# %%
# !pip install pymysql # mysql database connection library
# !jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10
# !python3 -m pip install --upgrade "git+https://github.com/nficano/pytube.git"   # pytube-12.0.0 설치
! pip install pydub

import os
import time                     # 딜레이 주기 위함
import datetime
import numpy as np
import pandas as pd             # Querying results to make dataframe(to divide datas)
import pymysql.cursors          # For Request Query String
from google.colab import drive


import pytube
from pytube import Search
from pydub import AudioSegment
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.4 MB/s
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-notebook", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/jupyter_core/application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.initialize(argv)
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 88, in inner
#     return method(app, *args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/notebook/notebookapp.py", line 1507, in initialize
#     self.init_webapp()
#   File "/usr/local/lib/python3.7/dist-packages/notebook/notebookapp.py", line 1297, in init_webapp
#     self.http_server.listen(port, self.ip)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/tcpserver.py", line 143, in listen
#     sockets = bind_sockets(port, address=address)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/netutil.py", line 168, in bind_sockets
#     sock.bind(sockaddr)
# OSError: [Errno 99] Cannot assign requested address
# Collecting git+https://github.com/nficano/pytube.git
#   Cloning https://github.com/nficano/pytube.git to /tmp/pip-req-build-iqqvvmag
#   Running command git clone -q https://github.com/nficano/pytube.git /tmp/pip-req-build-iqqvvmag
# Building wheels for collected packages: pytube
#   Building wheel for pytube (setup.py) ... done
#   Created wheel for pytube: filename=pytube-12.0.0-py3-none-any.whl size=56526 sha256=9690af62fa6970d0bb9a760db127127378893b7e129e07e0cfa73930f14f6b9a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6sx1wkap/wheels/f1/b5/78/12b4d0c5846b07ac841f094923d3b270c10c0a522dad8c2951
# Successfully built pytube
# Installing collected packages: pytube
# Successfully installed pytube-12.0.0
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
conn = pymysql.connect(host='csrd.cksngv0eixsu.ap-northeast-2.rds.amazonaws.com', port=3306, user='admin', password='qwerty1!', \
db='before-pp', charset='utf8', autocommit=True, cursorclass=pymysql.cursors.DictCursor)        # mysql connect inform
# select data in DB 
sql = "SELECT c.sg_name, c.sg_artists FROM bf_pl a join bf_tg b on a.pl_id = b.pl_id join bf_sg c on c.pl_id = b.pl_id WHERE pl_intro LIKE '클래식%'"
print(sql)
cur = conn.cursor() # open to query
cur.execute(sql)    # excute query

# %%
result = cur.fetchall() # merging result
conn.close()    # DB disconnect
print(result)   # Check Status
# Out:
# [{'sg_name': 'Mozart : Allegro In D Major K.626b/16', 'sg_artists': '조성진'}, {'sg_name': '바흐: 오르간 소나타 4번: 2. Andante [Adagio] (Transcr. by August Stradal)', 'sg_artists': 'Vikingur Olafsson'}, {'sg_name': '멘델스존: 무언가, 작품번호 62: 6. Allegretto grazioso (no.30)', 'sg_artists': 'Mischa Maisky, Sergio Tiempo'}, {'sg_name': '아델라이데', 'sg_artists': 'Matthias Goerne, Jan Lisiecki'}, {'sg_name': 'Richter : On The Nature Of Daylight (Entropy)', 'sg_artists': 'Max Richter, Louisa Fuller, Natalia Bonner, John Metcalfe, Ian Burdge, Chris Worsey'}, {'sg_name': 'Bruckner: 브루크너: Os justi meditabitur sapientiam', 'sg_artists': 'The Monteverdi Choir, John Eliot Gardiner'}, {'sg_name': "Schubert: 슈베르트: 환상곡 다장조 '방랑자' - 1. Allegro con fuoco ma non troppo", 'sg_artists': 'Maurizio Pollini'}, {'sg_name': '슈만: 어린이의 정경, 작품번호 15: 1. 미지의 나라들', 'sg_artists': 
Brahms : 4 Ballades No.1 In D Minor Op.10 (브람스 : 4개의 발라드 1번 라단조 작품번호 10)', 'sg_artists': 'Arturo Benedetti Michelangeli'}, {'sg_name': 'Brahms: 브람스: 피아노 4중주 1번 사단조 작품번호 25 - 4. Rondo alla Zingarese', 'sg_artists': 'Emil Gilels, Members Of The Amadeus Quartet'}, {'sg_name': 'Schumann : Dichterliebe Op.48 - I. Im Wunderschonen Monat Mai (슈만 : 시인의 사랑 작품번호 48 - 1번. 아름다운 5월에)', 'sg_artists': 'Fritz Wunderlich, Hubert Giesen'}, {'sg_name': '베토벤: 피아노 소나타 8번 다단조 작품번호 13 "비창": 2. Adagio cantabile', 'sg_artists': 'Wilhelm Kempff'}, {'sg_name': '바르토크: 피아노 협주곡 3번: 2. Adagio religioso', 'sg_artists': 'Geza Anda, Ferenc Fricsay, Deutsches Symphonie-Orchester Berlin'}, {'sg_name': '모차르트: 교향곡 40번 사단조, K.550: 1. Molto allegro', 'sg_artists': 'Herbert Von Karajan, Berliner Philharmoniker'}, {'sg_name': 'Beetho ...

# %%
df = pd.DataFrame(result)   # 전체 음악리스트 확인(playlist_id 기준이기 때문에 중복값 들어있음)
df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=True)  # 중복 처리
df
# Out:
#                                                sg_name  \
# 0                Mozart : Allegro In D Major K.626b/16
# 1    바흐: 오르간 소나타 4번: 2. Andante [Adagio] (Transcr. ...
# 2    멘델스존: 무언가, 작품번호 62: 6. Allegretto grazioso (no...
# 3                                                아델라이데
# 4        Richter : On The Nature Of Daylight (Entropy)
# ..                                                 ...
# 174  Beethoven: Sonata For Violin And Piano No.5 In...
# 175  Beethoven : Symphony No.5 In C Minor Op.67 'Fa...
# 176  Beethoven : Symphony No.6 In F Major Op.68 'Pa...
# 177  On Reflection (Music From "Black Mirror" TV Se...
# 178  She Was Running (From “My Brilliant Friend” TV...
#
#                                             sg_artists
# 0                                                  조성진
# 1                                    Vikingur Olafsson
# 2                         Mischa Maisky, Sergio Tiempo
# 3                        Matthias Goerne, Jan Lisiecki
# 4    Max Richter, Louisa Fuller, Natalia Bonner, Jo...
# ..                                                 ...
# 174                 David Garrett, Alexander Markovich
# 175              Wiener Philharmoniker, Andris Nelsons
# 176              Wiener Philharmoniker, Andris Nelsons
# 177                                        Max Richter
# 178                                        Max Richter
#
# [179 rows x 2 columns]

# %%
ext_lists = df.values.tolist() # pytube에서 검색어로 사용하기 위한 리스트 변환
audio_lists = []    # 검색결과가 나온 비디오 넣는 리스트
forbidden_lists = []    # 검색결과 없는 비디오 리스트 - 추후 DB 적용하기 위하여

for ext in ext_lists:
    try:
        StrClean = "-".join(ext)    # 노래 제목과 가수를 "-"를 구분자로 문자열 합치기
        yt = Search(StrClean).results[0]    # Search 메소드를 사용하여 검색하고, 그 결과의 1번째 결과 사용(빈도 상, 1 ~ 2번째 영상에 가장 관련있는 영상 표시)
    except:
        print("=================== Error Occured :  " + StrClean + " ===================")  # 에러 로그
        forbidden_lists.append(StrClean)    # 검색결과 없는 비디오 리스트 삽입
    audio_lists.append({StrClean : yt})     # 성공적으로 검색되는 비디오의 Youtube 객체 리스트 삽입
    # 추후 파일명으로 사용하여 라벨링 및 DB 적용을 수월하게 하기 위하여 딕셔너리 형태로 전달
# Out:
# =================== Error Occured :  레스피기: 류트를 위한 고풍의 무곡과 아리아 모음곡 3번: 3. 시칠리아나-Herbert Von Karajan, Berliner Philharmoniker ===================
# Unexpected renderer encountered.
# Renderer name: dict_keys(['movieRenderer'])
# Search term: Part Of Your World (인어공주 OST)-Royal Philharmonic Orchestra, Kaori Muraji
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['movieRenderer'])
# Search term: Reflection (뮬란 OST)-Royal Philharmonic Orchestra
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: It'll Be Okay-Shawn Mendes
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: 2000 Miles-GRACEY
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Take Me Home For Christmas-Dan + Shay
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['movieRenderer'])
# Search term: Main Theme (From 'The Dark Knight Rises')-Lindsey Stirling
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['reelShelfRenderer'])
# Search term: Smooth Criminal-David Garrett
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# Unexpected renderer encountered.
# Renderer name: dict_keys(['showingResultsForRenderer'])
# Search term: Mascani : Cavalleria Rusticana - Sancta Maria (마스카니 : 카발레리아 루스티카나 - 산타 마리아)-Andrea Bocelli, Myung-Whun Chung (정명훈), Orchestra Dell'Accademia Nazionale Di Santa Cecilia
# Please open an issue at https://github.com/pytube/pytube/issues and provide this log output.
# =================== Error Occured :  Rachmaninov : Rhapsody On A Theme Of Paganini In A Minor Op.43 - Var.XXIV (라흐마니노프 : 파가니니 주제에 의한 광시곡 -Valentina Lisitsa, Michael Francis, London Symphony Orchestra ===================

# %%
unfounded_lists = []    # 검색된 영상 중 필터링된, 관련성 떨어지는 목록용 리스트

def youtube_download(var):
    keys = str(list(var.items())[0][0])   # 딕셔너리에서 파일 이름으로 쓸 string 언패킹
    link = var.get(keys)                     # 딕셔너리에서 파일이름이 key값이므로, values 값인  (pytube.__main__.YouTube) 자료형 언패킹
    audio_streams = link.streams.filter(only_audio=True)    # pytube에서 지원하는 다양한 stream 중 Audio 속성을 가진 stream만
    # print(audio_streams)  # audio streams 처리 전체 정보

    flt1a = (int(link.length)) > 130    # 영상 길이 2분 10초 초과
    flt1b = (int(link.length)) < 1200    # 그래도 클래식이니까 영상 길이 20분 미만
    # flt1b = (int(link.length)) < 150    # 일부러 에러를 내기 위한 조건

    flt1 = flt1a and flt1b              # 위의 두 조건 동시에 만족하는 필터
    flt2 = ("official" in str(link.title).lower() or "audio" in str(link.title).lower() or "lylic" in str(link.title).lower())  
    # "official", "audio", "lylic" 중 제목에 하나라도 들어가는 영상 제목 통과

    # 내용 체크
    print(f'영상제목: {link.title},  영상 조회수: {link.views},  영상 길이: {link.length} sec. [{str(link.length // 60).zfill(2)}:{str(link.length % 60).zfill(2)}]')
    print(f'영상 URL: {link.watch_url}')
    print(f"# 1번 체크포인트 - 음원 길이(초):  {int(link.length)}, 타입은? : {type(int(link.length))}")
    print(f"# 2번 체크포인트 - 음원 제목(소문자):  {str(link.title).lower()}") 
    print(f"# 3번 체크포인트 - 2분 이상 20분 이하 길이:  {flt1}  ,  음원에 자주 붙은 문자열 포함 여부: {flt2}")


    # 저장 폴더 만들기 / Local 혹은 Server 환경에서 돌릴 경우 사용
    path = "/content/drive/Othercomputers/내 노트북/Project/Dataset/songs/download/"
    genre_dir = "classic"
    dir = path + genre_dir 
    if not os.path.exists('dir'):
        os.mkdir('dir')            

    ## filter()를 활용하여 파일 확장자 타입 등을 포함한 streams 처리
    if flt1 or flt2 == True:    # 위의 1, 2 조건 중 한가지라도 만족한다면 다운로드
        audio_streams = link.streams.filter(file_extension='mp4').get_by_itag(140)  # 여러개의 다운로드 스트림 선택해서 링크 하나 가져오기
        title = keys  # 영상 제목으로 파일명이 하고 싶다면? audio_streams.title 또는 link.title 사용 
        audio_streams.download(filename= title + '.mp3', output_path= dir)     # 설정한 파일명, 경로에 다운로드
        time.sleep(5)                                                          # 5초 휴지
        # print(f"=============== {keys.spilt('-')[1]}란 가수의 {keys.spilt('-')[0]} 란 노래 음원 다운로드 완료! ===============")    # 성공 로그
        print(f"#@#@#@#@#@#@#@ {keys} 다운로드 성공!")             # 성공 로그
        print("============================================== 구분선 ==============================================")
    else:
        print(f"^^^^^^^^^^^ Related Video Not Found : {keys}")  # 실패 로그
        unfounded_lists.append(keys)    # 실패 목록 리스트에 저장
        print("============================================== 구분선 ==============================================")

# %%
fail_cnt = 0
for fail_cnt ,audio in enumerate(audio_lists):
    try:
        youtube_download(audio)
    except:
        print(f"no error keep going, {fail_cnt}개째 다운로드 실패")
# Out:
# 영상제목: Seong Jin Cho – Mozart:  Allegro in D major, K 626b/16 (Live from Salzburg, 2021),  영상 조회수: 50732,  영상 길이: 112 sec. [01:52]
# 영상 URL: https://youtube.com/watch?v=IUq1hc9TYzU
# # 1번 체크포인트 - 음원 길이(초):  112, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  seong jin cho – mozart:  allegro in d major, k 626b/16 (live from salzburg, 2021)
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : Mozart : Allegro In D Major K.626b/16-조성진
# ============================================== 구분선 ==============================================
# 영상제목: Víkingur Ólafsson – Bach: Organ Sonata No. 4, BWV 528: II. Andante [Adagio] (Transcr. Stradal),  영상 조회수: 1848437,  영상 길이: 328 sec. [05:28]
# 영상 URL: https://youtube.com/watch?v=h3-rNMhIyuQ
# # 1번 체크포인트 - 음원 길이(초):  328, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  víkingur ólafsson – bach: organ sonata no. 4, bwv 528: ii. andante [adagio] (transcr. stradal)
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ 바흐: 오르간 소나타 4번: 2. Andante [Adagio] (Transcr. by August Stradal)-Vikingur Olafsson 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: Mendelssohn: Songs Without Words, Book 5, Op. 62 - 6. Allegretto Grazioso,  영상 조회수: 4107,  영상 길이: 129 sec. [02:09]
# 영상 URL: https://youtube.com/watch?v=du8WJdPi35o
# # 1번 체크포인트 - 음원 길이(초):  129, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  mendelssohn: songs without words, book 5, op. 62 - 6. allegretto grazioso
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : 멘델스존: 무언가, 작품번호 62: 6. Allegretto grazioso (no.30)-Mischa Maisky, Sergio Tiempo
# ============================================== 구분선 ==============================================
# 영상제목: Beethoven: Adelaide, Op. 46,  영상 조회수: 6583,  영상 길이: 330 sec. [05:30]
# 영상 URL: https://youtube.com/watch?v=TzNDKNLOyvc
# # 1번 체크포인트 - 음원 길이(초):  330, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  beethoven: adelaide, op. 46
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ 아델라이데-Matthias Goerne, Jan Lisiecki 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목:
 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  beethoven: piano sonata no. 8 in c minor, op. 13 "pathétique" - iii. rondo. allegro
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ 베토벤: 피아노 소나타 8번 다단조 작품번호 13 "비창": 3. Rondo. Allegro-Wilhelm Kempff 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: Kreisler: Liebesleid Song by Alexander Markovich and David Garrett,  영상 조회수: 1234,  영상 길이: 252 sec. [04:12]
# 영상 URL: https://youtube.com/watch?v=Z5_mAh-NGn8
# # 1번 체크포인트 - 음원 길이(초):  252, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  kreisler: liebesleid song by alexander markovich and david garrett
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ Kreisler: Liebesleid-David Garrett, Alexander Markovich 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: Beethoven: Violin Sonata No. 5 in F Major, Op. 24 "Spring" - I. Allegro,  영상 조회수: 20557,  영상 길이: 652 sec. [10:52]
# 영상 URL: https://youtube.com/watch?v=KuMOcMhPosM
# # 1번 체크포인트 - 음원 길이(초):  652, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  beethoven: violin sonata no. 5 in f major, op. 24 "spring" - i. allegro
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ Beethoven: Sonata For Violin And Piano No.5 In F, Op.24 - "Spring" - 1. Allegro-David Garrett, Alexander Markovich 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: Symphony No. 5 in C Minor, Op. 67: I. Allegro con brio,  영상 조회수: 5985,  영상 길이: 485 sec. [08:05]
# 영상 URL: https://youtube.com/watch?v=hzdUg9MmKg0
# # 1번 체크포인트 - 음원 길이(초):  485, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  symphony no. 5 in c minor, op. 67: i. allegro con brio
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ Beethoven : Symphony No.5 In C Minor Op.67 'Fate' - I. Allegro Con Brio (베토벤 : 교향곡 5번 다단조 작품번호 67 '운-Wiener Philharmoniker, Andris Nelsons 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: Symphony No. 6 in F Major, Op. 68 "Pastoral": II. Andante molto mosso,  영상 조회수: 26,  영상 길이: 802 sec. [13:22]
# 영상 URL: https://youtube.com/watch?v=_6rXzi7eqFY
# # 1번 체크포인트 - 음원 길이(초):  802, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  symphony no. 6 in f major, op. 68 "pastoral": ii. andante molto mosso
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ Beethoven : Symphony No.6 In F Major Op.68 'Pastoral' - II. Szene Am Bach. Andante Molto Mosso (베토벤 -Wiener Philharmoniker, Andris Nelsons 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: On Reflection (Music From "Black Mirror" TV Series),  영상 조회수: 13236,  영상 길이: 437 sec. [07:17]
# 영상 URL: https://youtube.com/watch?v=KFR9cpgiseA
# # 1번 체크포인트 - 음원 길이(초):  437, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  on reflection (music from "black mirror" tv series)
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ On Reflection (Music From "Black Mirror" TV Series)-Max Richter 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: She Was Running,  영상 조회수: 85196,  영상 길이: 129 sec. [02:09]
# 영상 URL: https://youtube.com/watch?v=eEitTK2svs8
# # 1번 체크포인트 - 음원 길이(초):  129, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  she was running
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : She Was Running (From “My Brilliant Friend” TV Series Soundtrack)-Max Richter
# ============================================== 구분선 ==============================================

# %%
def unfounded_df(ufs):   # unfounded_lists를 DB에 적용하기 위한 Dataframe 만들기
    df = pd.DataFrame(ufs, columns = ['col'])
    df['sg_name'] = df.col.str.split('-').str[0]
    df['sg_artists'] = df.col.str.split('-').str[1]
    df.drop(['col'], axis=1, inplace=True)
    return df

# %%
failed_df = unfounded_df(unfounded_lists)   # 데이터프레임 확인
failed_df
# Out:
#                                               sg_name  \
# 0               Mozart : Allegro In D Major K.626b/16
# 1   멘델스존: 무언가, 작품번호 62: 6. Allegretto grazioso (no...
# 2                      슈만: 5개의 노래, 작품번호 96: 3. 그의 목소리
# 3                                    리스트: 피아노 소나타 나단조
# 4             바흐: 크리스마스 오라토리오 / 1부: 2번 그것은 시간을 떠나 왔다네
# 5   드보르자크: 교향곡 9번 마단조 작품번호 95, B. 178 '신세계로부터': 4....
# 6        Bruckner : Symphony No.8 In C Minor WAB.108
# 7                      Schumann : Dichterliebe Op.48
# 8          모차르트: 교향곡 40번 사단조, K.550: 1. Molto allegro
# 9        Prokofiev: 프로코피예프: 세 개의 오렌지에 대한 사랑, 작품번호 33
# 10           Beethoven: Violin Concerto In D, Op. 61
# 11                                 Baranowski: Biafra
# 12                                     Bumblebee 2016
# 13  Chopin : 12 Etudes No.9 In G Flat Major Op.25 ...
# 14                 Mozart: Requiem In D Minor, K.626
# 15                 차이콥스키: 백조의 호수 모음곡, 작품번호 20a: 2. 왈츠
# 16  She Was Running (From “My Brilliant Friend” TV...
#
#                                            sg_artists
# 0                                                 조성진
# 1                        Mischa Maisky, Sergio Tiempo
# 2                                    Dietrich Fischer
# 3                                   Krystian Zimerman
# 4   Anthony Rolfe Johnson, English Baroque Soloist...
# 5             Rafael Kubelik, Berliner Philharmoniker
# 6    IV. Finale. Feierlich, Nicht Schnell (브루크너 : ...
# 7    I. Im Wunderschonen Monat Mai (슈만 : 시인의 사랑 작품...
# 8        Herbert Von Karajan, Berliner Philharmoniker
# 9                                                 행진곡
# 10                           1. Allegro ma non troppo
# 11  Daniel Hope, Jacques Ammon, Deutsches Kammeror...
# 12                                             Maksim
# 13                                       Tamas Vasary
# 14                         3. Sequentia: a. Dies irae
# 15         Wiener Philharmoniker, Herbert Von Karajan
# 16                                        Max Richter

# %%
ext_lists2 = failed_df.values.tolist() # pytube에서 검색어로 사용하기 위한 리스트 변환

# %%
audio_lists2 = []    # 검색결과가 나온 비디오 넣는 리스트
forbidden_lists2 = []    # 검색결과 없는 비디오 리스트 - 추후 DB 적용하기 위하여

for ext in ext_lists2:
    try:
        StrClean = "-".join(ext)    # 노래 제목과 가수를 "-"를 구분자로 문자열 합치기
        yt = Search(StrClean).results[1]    # Search 메소드를 사용하여 검색하고, 1번째 영상에서 에러가 발생했으므로 2번째 영상 선택
    except:
        print("=================== Error Occured :  " + StrClean + " ===================")  # 에러 로그
        forbidden_lists2.append(StrClean)    # 검색결과 없는 비디오 리스트 삽입
    audio_lists2.append({StrClean : yt})     # 성공적으로 검색되는 비디오의 Youtube 객체 리스트 삽입
    # 추후 파일명으로 사용하여 라벨링 및 DB 적용을 수월하게 하기 위하여 딕셔너리 형태로 전달

# %%
forbidden_lists2
# Out:
# []

# %%
fail_cnt = 0
for fail_cnt ,audio in enumerate(audio_lists2):
    try:
        youtube_download(audio)
    except:
        print(f"no error keep going, {fail_cnt}개째 다운로드 실패")
# Out:
# 영상제목: Mozart: Allegro in D Major, K. 626b/16,  영상 조회수: 106175,  영상 길이: 101 sec. [01:41]
# 영상 URL: https://youtube.com/watch?v=gHifLVl8yQs
# # 1번 체크포인트 - 음원 길이(초):  101, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  mozart: allegro in d major, k. 626b/16
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : Mozart : Allegro In D Major K.626b/16-조성진
# ============================================== 구분선 ==============================================
# 영상제목: Felix Mendelssohn-Songs Without Words Op.62-6 `Fruhlingslied'-allegretto grazioso,  영상 조회수: 185,  영상 길이: 209 sec. [03:29]
# 영상 URL: https://youtube.com/watch?v=yIEpzOyDkBE
# # 1번 체크포인트 - 음원 길이(초):  209, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  felix mendelssohn-songs without words op.62-6 `fruhlingslied'-allegretto grazioso
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ 멘델스존: 무언가, 작품번호 62: 6. Allegretto grazioso (no.30)-Mischa Maisky, Sergio Tiempo 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: "Stucke im Volkston", Op. 102 (Part 1) - Robert Schumann,  영상 조회수: 196,  영상 길이: 695 sec. [11:35]
# 영상 URL: https://youtube.com/watch?v=j6u60VjM8ac
# # 1번 체크포인트 - 음원 길이(초):  695, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  "stucke im volkston", op. 102 (part 1) - robert schumann
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ 슈만: 5개의 노래, 작품번호 96: 3. 그의 목소리-Dietrich Fischer 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: Liszt: Piano Sonata in B minor, S.178,  영상 조회수: 36117,  영상 길이: 1837 sec. [30:37]
# 영상 URL: https://youtube.com/watch?v=GfgBORsUhW4
# # 1번 체크포인트 - 음원 길이(초):  1837, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  liszt: piano sonata in b minor, s.178
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : 리스트: 피아노 소나타 나단조-Krystian Zimerman
# ============================================== 구분선 ==============================================
# 영상제목: J.S. Bach: Christmas Oratorio, BWV 248 / Part One - For The First Day Of Christmas - No. 2...,  영상 조회수: 114,  영상 길이: 71 sec. [01:11]
# 영상 URL: https://youtube.com/watch?v=bqbW13nYpNQ
# # 1번 체크포인트 - 음원 길이(초):  71, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  j.s. bach: christmas oratorio, bwv 248 / part one - for the first day of christmas - no. 2...
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : 바흐: 크리스마스 오라토리오 / 1부: 2번 그것은 시간을 떠나 왔다네-Anthony Rolfe Johnson, English Baroque Soloists, John Eliot Gardiner
# ============================================== 구분선 ==============================================
# 영상제목: Dvorák: Symphony No.9 In E Minor, Op.95, B.178 - "From The New World" - 4. Allegro con fuoco,  영상 조회수: 2567,  영상 길이: 672 sec. [11:12]
# 영상 URL: https://youtube.com/watch?v=VoWa9gUMYwU
# # 1번 체크포인트 - 음원 길이(초):  672, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  dvorák: symphony no.9 in e minor, op.95, b.178 - "from the new world" - 4. allegro con fuoco
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  True  ,  음원에 자주 붙은 문자열 포함 여부: False
# #@#@#@#@#@#@#@ 드보르자크: 교향곡 9번 마단조 작품번호 95, B. 178 '신세계로부터': 4. Allegro con fuoco-Rafael Kubelik, Berliner Philharmoniker 다운로드 성공!
# ============================================== 구분선 ==============================================
# 영상제목: Symphony No. 8 in C Minor, WAB 108 (Edition Haas) : IV. Finale - Feierlich, nicht schnell,  영상 조회수: 4213,  영상 길이: 1425 sec. [23:45]
# 영상 URL: https://youtube.com/watch?v=yCzFpFK5JC0
# # 1번 체크포인트 - 음원 길이(초):  1425, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  symphony no. 8 in c minor, wab 108 (edition haas) : iv. finale - feierlich, nicht schnell
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : Bruckner : Symphony No.8 In C Minor WAB.108 - IV. Finale. Feierlich, Nicht Schnell (브루크너 : 교향곡 8번 다단
# ============================================== 구분선 ==============================================
# 영상제목: 슈만: 시인의사랑, Op.48 [피셔-디스카우/횔] (하이네),  영상 조회수: 11917,  영상 길이: 1816 sec. [30:16]
# 영상 URL: https://youtube.com/watch?v=kQqgMYEa1xw
# # 1번 체크포인트 - 음원 길이(초):  1816, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : Chopin : 12 Etudes No.9 In G Flat Major Op.25 'Butterfly Wings' (쇼팽 : 12개의 연습곡 9번 내림 사장조 작품번호 25 '나비-Tamas Vasary
# ============================================== 구분선 ==============================================
# 영상제목: Mozart: Requiem in D Minor, K.626 - 3a. Sequientia: Dies irae,  영상 조회수: 143656,  영상 길이: 113 sec. [01:53]
# 영상 URL: https://youtube.com/watch?v=FGqoU9NIjZw
# # 1번 체크포인트 - 음원 길이(초):  113, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  mozart: requiem in d minor, k.626 - 3a. sequientia: dies irae
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : Mozart: Requiem In D Minor, K.626 - 3. Sequentia: a. Dies irae
# ============================================== 구분선 ==============================================
# 영상제목: Pyotr Ilyich Tchaikovsky – The Three Ballet Suites – Herbert von Karajan, Wiener Philharmoniker,  영상 조회수: 336,  영상 길이: 4159 sec. [69:19]
# 영상 URL: https://youtube.com/watch?v=lWny5EQBO08
# # 1번 체크포인트 - 음원 길이(초):  4159, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  pyotr ilyich tchaikovsky – the three ballet suites – herbert von karajan, wiener philharmoniker
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: False
# ^^^^^^^^^^^ Related Video Not Found : 차이콥스키: 백조의 호수 모음곡, 작품번호 20a: 2. 왈츠-Wiener Philharmoniker, Herbert Von Karajan
# ============================================== 구분선 ==============================================
# 영상제목: My Brilliant Friend (Official Soundtrack) - She Was Running - Max Richter,  영상 조회수: 255,  영상 길이: 129 sec. [02:09]
# 영상 URL: https://youtube.com/watch?v=XXGkbvDDAco
# # 1번 체크포인트 - 음원 길이(초):  129, 타입은? : <class 'int'>
# # 2번 체크포인트 - 음원 제목(소문자):  my brilliant friend (official soundtrack) - she was running - max richter
# # 3번 체크포인트 - 2분 이상 10분 이하 길이:  False  ,  음원에 자주 붙은 문자열 포함 여부: True
# #@#@#@#@#@#@#@ She Was Running (From “My Brilliant Friend” TV Series Soundtrack)-Max Richter 다운로드 성공!
# ============================================== 구분선 ==============================================

# %%
path = "/content/drive/Othercomputers/내 노트북/Project/Dataset/songs/download/"
genre_dir = "classic"
dir  = path + genre_dir
def song_names(dir):
    files = list(os.listdir(dir))
    return files    # filename

filename = song_names(dir)
len(filename)
# Out:
# 166

# %%
def load_song(filename):
    song = f'{filename}'
    path = f'{dir}/{filename}'
    return song, path
songs = []
paths = []

for file in filename:
    song, path = load_song(file)
    songs.append(f"{song}")
    paths.append(f"{path}")

# %%
ths_lists = []

for file in paths:
    filename, file_extension = os.path.splitext(file)
    if file_extension == ".mp3":
        dst = file.replace(".mp3","")+".wav"                                                             
        audSeg = AudioSegment.from_file(file, format="mp4")  # convert wav from mp3 
        audSeg.export(dst, format="wav")
        song = AudioSegment.from_wav(dst)
        sec = 10000     # 10초 변수
        block = song[sec * 8 : sec * 11]     # 1분 20초 ~ 1분 50초 구간만 사용하기 위한 변수(하이라이트 추출)
        down_dir = "/content/drive/Othercomputers/내 노트북/Project/Dataset/songs/download/"
        inner_dir = f"converted/" # 테스트 버전 2
        dir = f"{down_dir}{genre_dir}/{inner_dir}"    
        if not os.path.exists(dir):
            os.mkdir(dir)
        name = f'{file.replace(".mp3","").replace(f"{down_dir}{genre_dir}/","")}_30.wav'
        export_path = dir + name
        block.export(export_path, format='wav', parameters=["-q:a", "10", "-ac", "1"])
        print(f"Converting Successful // converted filename: {export_path}")
        ths_lists.append(export_path)
    else:
        print(file)

# %%
ths_lists
