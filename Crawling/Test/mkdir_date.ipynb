# %%
import os
import time

def get_today():
	now = time.localtime()
	s = "%04d-%02d-%02d" % (now.tm_year, now.tm_mon, now.tm_mday)
	return s

today = get_today()
today
# Out:
# '2022-03-21'

# %%
inner_dir = "/content/sample_data/"+ today
if not os.path.exists(inner_dir):
    os.makedirs(inner_dir)
